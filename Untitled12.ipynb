# %%
# !pip install inference_sdk

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Nrp2Q5XX7efEPeKjsRix")
project = rf.workspace("seniordesign-qxz6s").project("classifierrocks")
version = project.version(1)
dataset = version.download("folder")# import the inference-sdk
from inference_sdk import InferenceHTTPClient

# initialize the client
CLIENT = InferenceHTTPClient(
    api_url="http://detect.roboflow.com",
    api_key="Nrp2Q5XX7efEPeKjsRix"
)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 631.4 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 1.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 449.2 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 579.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 509.2 kB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.9.0.80
#     Uninstalling opencv-python-headless-4.9.0.80:
#       Successfully uninstalled opencv-python-headless-4.9.0.80
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
# ...

# %%
# import the inference-sdk
from inference_sdk import InferenceHTTPClient

# initialize the client
CLIENT = InferenceHTTPClient(
    api_url="http://detect.roboflow.com",
    api_key="Nrp2Q5XX7efEPeKjsRix"
)
result = CLIENT.infer("C:\\Users\\rrose\\OneDrive\\Desktop\\Sandstone3.png", model_id="classifierrocks/1")

result
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/inference_sdk/http/client.py in decorate(*args, **kwargs)
#      81         try:
# ---> 82             return function(*args, **kwargs)
#      83         except HTTPError as error:
#
# /usr/local/lib/python3.10/dist-packages/inference_sdk/http/client.py in list_loaded_models(self)
#     574         response = requests.get(f"{self.__api_url}/model/registry")
# --> 575         response.raise_for_status()
#     576         response_payload = response.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://detect.roboflow.com/model/registry
#
# ...
